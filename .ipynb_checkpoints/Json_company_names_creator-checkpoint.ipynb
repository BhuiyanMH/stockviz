# %%
import pandas as pd
import json

# %%
csv = pd.read_csv("data\\companies_stock_price_worldwide.csv")

# %%
csv = pd.read_csv("data\\companies_stock_price_worldwide.csv")
news = pd.read_csv("data\\news.csv", delimiter='\t')

companies_have_news = news.Company.unique()
csv["has_news"] = np.where(csv["Company"].isin(companies_have_news), 1, 0)

# %%
list_sectors = list(csv['Sector'].unique())

# %%
list_companies = list(csv['Company'].unique())

# %%
list_companies

# %%
ex_comp = []
for c in list_companies:
    x = csv.loc[csv['Company'] == c]
    ex_comp.append(x.iloc[0,:])

# %%
obj = {"name": "Sectors",
      'children':[]}
for sec in list_sectors:
    sec_obj = {}
    sec_obj['name'] = sec
    sec_obj['children'] = []
    obj['children'].append(sec_obj)

# %%
import math

def add_to_list(company, obj):
    # Save the sector of the company
    for sector in obj['children']:
        if sector['name'] == company['Sector']:
            sector['children'].append({'name': company['Company'],'value':math.ceil(company['Close'])})
    return obj

# %%
ex_comp = []
for c in list_companies:
    x = csv.loc[csv['Company'] == c]
    # Take the row corresponding to the last date
    ex_comp.append(x.iloc[0,:])

# %%
for x in ex_comp:
    add_to_list(x, obj)

# %%
json_string = json.dumps(obj,ensure_ascii=False).encode('utf8')
json_string.decode()
# Out:
# '{"name": "Sectors", "children": [{"name": "Financial Services", "children": [{"name": "Intesa Sanpaolo S.p.A.", "value": 3}, {"name": "Banco Santander, S.A.", "value": 4}, {"name": "ING Groep N.V.", "value": 10}, {"name": "AXA SA", "value": 22}, {"name": "BNP Paribas SA", "value": 44}, {"name": "Allianz SE", "value": 224}, {"name": "Deutsche Börse AG", "value": 159}, {"name": "Münchener Rückversicherungs-Gesellschaft Aktiengesellschaft in München", "value": 248}, {"name": "AIA Group Limited", "value": 87}, {"name": "China Construction Bank Corporation", "value": 1}, {"name": "Ping An Insurance (Group) Company of China, Ltd.", "value": 12}, {"name": "Industrial and Commercial Bank of China Limited", "value": 1}, {"name": "Hong Kong Exchanges and Clearing Limited", "value": 274}, {"name": "United Overseas Bank Limited", "value": 18}, {"name": "China Life Insurance Company Limited", "value": 3}, {"name": "China Merchants Bank Co., Ltd.", "value": 5}, {"name": "Shinhan Financial Group Co., Ltd.", "value": 276}, {"name": "Hang Seng Bank Limited", "value": 181}, {"name": "KB Financial Group Inc.", "value": 268}, {"name": "Cathay Financial Holding Co., Ltd.", "value": 2}, {"name": "Aflac Incorporated", "value": 50}, {"name": "The Allstate Corporation", "value": 101}, {"name": "American Express Company", "value": 116}, {"name": "American International Group, Inc.", "value": 51}, {"name": "Ameriprise Financial, Inc.", "value": 124}, {"name": "Aon Plc", "value": 191}, {"name": "Arthur J. Gallagher & Co.", "value": 88}, {"name": "Assurant, Inc.", "value": 121}, {"name": "Bank of America Corporation", "value": 27}, {"name": "The Bank of New York Mellon Corporation", "value": 41}, {"name": "BlackRock, Inc.", "value": 402}, {"name": "Capital One Financial Corporation", "value": 84}, {"name": "Cboe Global Markets, Inc.", "value": 118}, {"name": "The Charles Schwab Corporation", "value": 38}, {"name": "Chubb Limited", "value": 154}, {"name": "Cincinnati Financial Corporation", "value": 109}, {"name": "Citigroup Inc.", "value": 62}, {"name": "Citizens Financial Group, Inc.", "value": 32}, {"name": "CME Group Inc.", "value": 211}, {"name": "Comerica Incorporated", "value": 56}, {"name": "Discover Financial Services", "value": 77}, {"name": "Everest Re Group, Ltd.", "value": 236}, {"name": "Fifth Third Bancorp", "value": 25}, {"name": "First Republic Bank", "value": 88}, {"name": "Franklin Resources, Inc.", "value": 25}, {"name": "Globe Life Inc.", "value": 88}, {"name": "The Goldman Sachs Group, Inc.", "value": 195}, {"name": "The Hartford Financial Services Group, Inc.", "value": 58}, {"name": "Huntington Bancshares Incorporated", "value": 13}, {"name": "Intercontinental Exchange, Inc.", "value": 93}, {"name": "Invesco Ltd.", "value": 15}, {"name": "JPMorgan Chase & Co.", "value": 104}, {"name": "KeyCorp", "value": 16}, {"name": "Lincoln National Corporation", "value": 50}, {"name": "Loews Corporation", "value": 48}, {"name": "M&T Bank Corporation", "value": 139}, {"name": "MarketAxess Holdings Inc.", "value": 400}, {"name": "Marsh & McLennan Companies, Inc.", "value": 97}, {"name": "Mastercard Incorporated", "value": 279}, {"name": "MetLife, Inc.", "value": 43}, {"name": "Moody\'s Corporation", "value": 212}, {"name": "Morgan Stanley", "value": 40}, {"name": "MSCI Inc.", "value": 232}, {"name": "Nasdaq, Inc.", "value": 98}, {"name": "Northern Trust Corporation", "value": 84}, {"name": "PayPal Holdings, Inc.", "value": 107}, {"name": "People\'s United Financial, Inc.", "value": 14}, {"name": "The PNC Financial Services Group, Inc.", "value": 122}, {"name": "Principal Financial Group, Inc.", "value": 50}, {"name": "The Progressive Corporation", "value": 73}, {"name": "Prudential Financial, Inc.", "value": 75}, {"name": "Raymond James Financial, Inc.", "value": 76}, {"name": "Regions Financial Corporation", "value": 14}, {"name": "S&P Global Inc.", "value": 257}, {"name": "State Street Corporation", "value": 48}, {"name": "SVB Financial Group", ...

# %%
jsonStr = json.dumps("Moët")
with open('personal.txt', 'w', encoding='utf-8') as json_file:
    json.dump(jsonStr, json_file, ensure_ascii=False)
